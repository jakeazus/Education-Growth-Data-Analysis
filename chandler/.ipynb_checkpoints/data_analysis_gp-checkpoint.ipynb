# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np
import requests
import json
import csv

# %%
file_to_load = "/Users/Chibbbins/desktop/data-analysis-project-1/chandler/Resources/EdStatsData.csv"


raw_education_data = pd.read_csv(file_to_load)

raw_education_data.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         2000       2001       2002       2003       2004       2005  ...  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 1        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 2        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 3        NaN        NaN        NaN        NaN        NaN        NaN  ...
# ...

# %%
raw_education_data_UK = raw_education_data.loc[(raw_education_data['Country Name'] == "United Kingdom")]

ind_pull = ["Government expenditure in pre-primary institutions as % of GDP (%)",
"Government expenditure in primary institutions as % of GDP (%)",
"Government expenditure in secondary institutions education as % of GDP (%)",
"Government expenditure on education as % of GDP (%)",
"Government expenditure on post-secondary non-tertiary education as % of GDP (%)",
"Government expenditure on pre-primary education as % of GDP (%)",
"Government expenditure on primary education as % of GDP (%)",
"Government expenditure on secondary and post-secondary non-tertiary vocational education as % of GDP (%)",
"Government expenditure on secondary education as % of GDP (%)",
"Government expenditure on tertiary education as % of GDP (%)",
"Government expenditure in educational institutions as % of GDP (%)"]

clean_UK = pd.DataFrame()

for x in ind_pull:

    clean_UK = clean_UK.append(raw_education_data_UK.loc[raw_education_data_UK['Indicator Name'] == x])     

finished_UK = clean_UK.drop(columns=["2000", "2012", "2013", "2014", "2015","2016", "2017", "2020", "2025",
                                     "2030", "2035", "2040", "2045", "2050", "2055", "2060", "2065", "2070", "2075",
                                     "2080", "2085", "2090", "2095", "2100", "Country Code", "Indicator Code"])
finished_UK.head()
# Out:
#           Country Name                                     Indicator Name  \
# 844206  United Kingdom  Government expenditure in pre-primary institut...
# 844207  United Kingdom  Government expenditure in primary institutions...
# 844208  United Kingdom  Government expenditure in secondary institutio...
# 844210  United Kingdom  Government expenditure on education as % of GD...
# 844211  United Kingdom  Government expenditure on post-secondary non-t...
#
#            2001     2002     2003     2004     2005     2006     2007  \
# 844206  0.41348  0.42530  0.33098  0.32788  0.26380  0.25860  0.22677
# 844207  1.09703  1.17017  1.29959  1.28363  1.34868  1.44352  1.50605
# 844208  2.11947  2.33032  2.45788  2.35278  2.32328  1.66063  1.64455
# 844210  4.17893  4.71955  4.88927  4.80557  5.01561  5.04410  4.96506
# 844211      NaN      NaN      NaN      NaN      NaN      NaN  0.01207
#
#            2008     2009     2010     2011
# 844206  0.22212  0.22133  0.28151  0.30557
# ...

# %%
raw_education_data_SP = raw_education_data.loc[(raw_education_data['Country Name'] == "Spain")]

clean_SP = pd.DataFrame()

for x in ind_pull:

    clean_SP = clean_SP.append(raw_education_data_SP.loc[raw_education_data_SP['Indicator Name'] == x])     

finished_SP = clean_SP.drop(columns=["2000", "2012", "2013", "2014", "2015","2016", "2017", "2020", "2025",
                                     "2030", "2035", "2040", "2045", "2050", "2055", "2060", "2065", "2070", "2075",
                                     "2080", "2085", "2090", "2095", "2100", "Country Code", "Indicator Code"])
finished_SP.head()
# Out:
#        Country Name                                     Indicator Name  \
# 745251        Spain  Government expenditure in pre-primary institut...
# 745252        Spain  Government expenditure in primary institutions...
# 745253        Spain  Government expenditure in secondary institutio...
# 745255        Spain  Government expenditure on education as % of GD...
# 745256        Spain  Government expenditure on post-secondary non-t...
#
#            2001     2002     2003     2004     2005     2006     2007  \
# 745251  0.37978  0.40792  0.44546  0.46739  0.50789  0.53022  0.56801
# 745252  1.06430  1.05633  1.05884  1.06360  1.04927  1.05401  1.05895
# 745253  1.70429  1.69192  1.65456  1.62306  1.60096  1.60266  1.58841
# 745255  4.11710  4.13762  4.16962  4.15031  4.12810  4.15923  4.23648
# 745256      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#            2008     2009     2010     2011
# 745251  0.61639  0.68963  0.66530  0.67182
# ...

# %%
ref_yr = "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010", "2011"
plt.plot(ref_yr, finished_SP.iloc[0, 2:13], label="Spain", marker='o')
plt.plot(ref_yr, finished_UK.iloc[0, 2:13], label="UK", marker='o')
plt.title("Spain vs United Kingdom's Government expenditure in pre-primary institutions as % of GDP")
plt.xlabel("years")
plt.ylabel("Government expenditure as % of GDP")
plt.legend()

# %%
plt.plot(ref_yr, finished_SP.iloc[1, 2:13], label="Spain", marker='o')
plt.plot(ref_yr, finished_UK.iloc[1, 2:13], label="UK", marker='o')


plt.title("Spain vs United Kingdom's Government expenditure in primary institutions as % of GDP")
plt.xlabel("years")
plt.ylabel("Government expenditure as % of GDP")
plt.legend()

# %%
plt.plot(ref_yr, finished_SP.iloc[2, 2:13], label="Spain", marker='o')
plt.plot(ref_yr, finished_UK.iloc[2, 2:13], label="UK", marker='o')
plt.title("Spain vs United Kingdom's Government expenditure in secondary institutions education as % of GDP")
plt.xlabel("years")
plt.ylabel("Government expenditure as % of GDP")
plt.legend()

# %%
plt.plot(ref_yr, finished_SP.iloc[3, 2:13], label="Spain", marker='o')
plt.plot(ref_yr, finished_UK.iloc[3, 2:13], label="UK", marker='o')
plt.title("Spain vs United Kingdom's Government expenditure on education as % of GDP")
plt.xlabel("years")
plt.ylabel("Government expenditure as % of GDP")
plt.legend()

# %%
plt.plot(ref_yr, finished_SP.iloc[5, 2:13], label="Spain", marker='o')
plt.plot(ref_yr, finished_UK.iloc[5, 2:13], label="UK", marker='o')
plt.title("Spain vs United Kingdom's Government expenditure on pre-primary education as % of GDP")
plt.xlabel("years")
plt.ylabel("Government expenditure as % of GDP")
plt.legend()

# %%
plt.plot(ref_yr, finished_SP.iloc[6, 2:13], label="Spain", marker='o')
plt.plot(ref_yr, finished_UK.iloc[6, 2:13], label="UK", marker='o')
plt.title("Spain vs United Kingdom's Government expenditure on primary education as % of GDP")
plt.xlabel("years")
plt.ylabel("Government expenditure as % of GDP")
plt.legend()

# %%
plt.plot(ref_yr, finished_SP.iloc[8, 2:13], label="Spain", marker='o')
plt.plot(ref_yr, finished_UK.iloc[8, 2:13], label="UK", marker='o')
plt.title("Spain vs United Kingdom's Government expenditure on secondary education as % of GDP")
plt.xlabel("years")
plt.ylabel("Government expenditure as % of GDP")
plt.legend()

# %%
plt.plot(ref_yr, finished_SP.iloc[9, 2:13], label="Spain", marker='o')
plt.plot(ref_yr, finished_UK.iloc[9, 2:13], label="UK", marker='o')
plt.title("Spain vs United Kingdom's Government expenditure on tertiary education as % of GDP")
plt.xlabel("years")
plt.ylabel("Government expenditure as % of GDP")
plt.legend()

# %%
plt.plot(ref_yr, finished_SP.iloc[10, 2:13], label="Spain", marker='o')
plt.plot(ref_yr, finished_UK.iloc[10, 2:13], label="UK", marker='o')
plt.title("Spain vs United Kingdom's Government expenditure in educational institutions as % of GDP")
plt.xlabel("years")
plt.ylabel("Government expenditure as % of GDP")
plt.legend()

# %%
Compare_UK = raw_education_data.loc[(raw_education_data['Country Name'] == "United Kingdom")]

ind_pull1 = ["Unemployment, total (% of total labor force)"]

clean_compare_UK = pd.DataFrame()

for x in ind_pull1:

    clean_compare_UK = clean_compare_UK.append(Compare_UK.loc[Compare_UK['Indicator Name'] == x])     

finished_compare_UK = clean_compare_UK.drop(columns=["2000", "2012", "2013", "2014", "2015","2016", "2017", "2020", "2025",
                                     "2030", "2035", "2040", "2045", "2050", "2055", "2060", "2065", "2070", "2075",
                                     "2080", "2085", "2090", "2095", "2100", "Country Code", "Indicator Code"])
finished_compare_UK.head()
# Out:
#           Country Name                                Indicator Name  2001  \
# 846298  United Kingdom  Unemployment, total (% of total labor force)   4.7
#
#         2002  2003  2004  2005  2006  2007  2008  2009  2010  2011
# 846298   5.0   4.8   4.6   4.8   5.4   5.3   5.6   7.5   7.8   8.0

# %%
Compare_SP = raw_education_data.loc[(raw_education_data['Country Name'] == "Spain")]

ind_pull2 = ["Unemployment, total (% of total labor force)"]

clean_compare_SP = pd.DataFrame()

for x in ind_pull1:

    clean_compare_SP = clean_compare_SP.append(Compare_SP.loc[Compare_SP['Indicator Name'] == x])     

finished_compare_SP = clean_compare_SP.drop(columns=["2000", "2012", "2013", "2014", "2015","2016", "2017", "2020", "2025",
                                     "2030", "2035", "2040", "2045", "2050", "2055", "2060", "2065", "2070", "2075",
                                     "2080", "2085", "2090", "2095", "2100", "Country Code", "Indicator Code"])
finished_compare_SP.head()
# Out:
#        Country Name                                Indicator Name  2001  2002  \
# 747343        Spain  Unemployment, total (% of total labor force)  10.3  11.1
#
#         2003  2004  2005  2006  2007  2008  2009  2010  2011
# 747343  11.3  11.1   9.1   8.5   8.2  11.3  17.9  19.9  21.4

# %%
from matplotlib.lines import Line2D

fig,ax = plt.subplots()
ax.plot(ref_yr, finished_UK.iloc[3, 2:13], marker='o', color='b')
ax.plot(ref_yr, finished_SP.iloc[3, 2:13], marker='o', color='r')
ax.set_xlabel("years")
ax.set_ylabel("Government expenditure as % of GDP")
ax2 = ax.twinx()
ax2.plot(ref_yr, finished_compare_UK.iloc[0, 2:13], marker='v', color='b')
ax2.plot(ref_yr, finished_compare_SP.iloc[0, 2:13], marker='v', color='r')
ax2.set_ylabel("Unemployment, total (% of total labor force)")
plt.title("Government expenditure on education as % of GDP and Unemployment, total (% of total labor force) over 10 yr period")



legend_elements = [Line2D([0], [0],marker='o', color='b', lw=1, label="UK govt exp"), Line2D([0], [0],marker='o', color='r', lw=1, label="SP govt exp"),
                   Line2D([0], [0],marker='v', color='b', lw=1, label="UK unemployment"), Line2D([0], [0],marker='v', color='r', lw=1, label="SP unemployment")]
ax.legend(handles=legend_elements)
plt.show()
