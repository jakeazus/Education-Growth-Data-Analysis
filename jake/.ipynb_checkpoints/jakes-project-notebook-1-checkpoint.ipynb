# %%
import pandas as pd 
import requests
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np
import json

# %%
csv_file = "Resources/EDSTAT_UK&SP.csv"
education_data = pd.read_csv(csv_file)
education_data.head()
# Out:
#      Country Name Country Code  \
# 0  United Kingdom          GBR
# 1  United Kingdom          GBR
# 2  United Kingdom          GBR
# 3  United Kingdom          GBR
# 4  United Kingdom          GBR
#
#                                       Indicator Name         2000  \
# 0  Expenditure on primary as % of government expe...  24.71134949
# 1  Expenditure on primary as % of total governmen...  2.980230093
# 2  Expenditure on secondary and post-secondary no...          NaN
# 3  Expenditure on secondary and post-secondary no...          NaN
# 4  Expenditure on secondary as % of government ex...  48.73329926
#
#           2001         2002         2003         2004         2005  \
# 0  24.98936081  23.62890053   25.4773407  26.19923973  26.46495056
# 1  3.071850061  3.205369949  3.469130039  3.394249916  3.489840031
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4  48.35630035  47.14807129  48.27423096  47.88209152  45.38877869
#
#           2006         2007         2008         2009         2010  \
# 0  29.44553947  30.64546967  31.57509041  31.11967087  30.09235001
# 1  3.893019915   3.98781991  4.094099998   3.92324996  3.900079966
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4  43.31438065  45.10861969  47.03944016  48.91957092  48.31803894
#
#           2011 2012         2013         2014         2015 2016
# 0  30.77206039  NaN  29.78849983  28.91542053   32.1665802  NaN
# 1  3.913100004  NaN  3.864939928          NaN          NaN  NaN
# 2          NaN  NaN     10.55173          NaN          NaN  NaN
# 3          NaN  NaN      1.36905          NaN          NaN  NaN
# 4   41.5705986  NaN  40.13864136  41.13214874  41.03583145  NaN

# %%
labor_force_total_df = education_data.loc[education_data["Indicator Name"] == "Labor force, total"]
unemployment_total_df = education_data.loc[education_data["Indicator Name"] == "Unemployment, total (% of total labor force)"]
unemployment_male = education_data.loc[education_data["Indicator Name"] == "Unemployment, male (% of male labor force)"]
unemployment_female = education_data.loc[education_data["Indicator Name"] == "Unemployment, female (% of female labor force)"]
labor_force_advanced_education_total = education_data.loc[education_data["Indicator Name"] == "Labor force with advanced education (% of total)"]
labor_force_advanced_education_male = education_data.loc[education_data["Indicator Name"] == "Labor force with advanced education, male (% of male labor force)"]
labor_force_advanced_education_female = education_data.loc[education_data["Indicator Name"] == "Labor force with advanced education, female (% of female labor force)"]

# %%
total_df = education_data.loc[
    (education_data["Indicator Name"] == "Labor force, total") | 
    (education_data["Indicator Name"] == "Unemployment, total (% of total labor force)") |  
    (education_data["Indicator Name"] == "Unemployment, male (% of male labor force)"  ) | 
    (education_data["Indicator Name"] == "Unemployment, female (% of female labor force)" ) | 
    (education_data["Indicator Name"] == "Labor force with advanced education (% of total)" ) | 
    (education_data["Indicator Name"] == "Labor force with advanced education, male (% of male labor force)" ) | 
    (education_data["Indicator Name"] == "Labor force with advanced education, female (% of female labor force)" ) 
]


indicator_table_df = total_df.set_index('Indicator Name')
clean_indicator_table = indicator_table_df.drop(columns=['2000', '2012', '2013', "2014", "2015", "2016"])
clean_indicator_table ['2001'] = (clean_indicator_table ['2001'].astype(float)).round(2)
clean_indicator_table ['2002'] = (clean_indicator_table ['2002'].astype(float)).round(2)
clean_indicator_table ['2003'] = (clean_indicator_table ['2003'].astype(float)).round(2)
clean_indicator_table ['2004'] = (clean_indicator_table ['2004'].astype(float)).round(2)
clean_indicator_table ['2005'] = (clean_indicator_table ['2005'].astype(float)).round(2)
clean_indicator_table ['2006'] = (clean_indicator_table ['2006'].astype(float)).round(2)
clean_indicator_table ['2007'] = (clean_indicator_table ['2007'].astype(float)).round(2)
clean_indicator_table ['2008'] = (clean_indicator_table ['2008'].astype(float)).round(2)
clean_indicator_table ['2009'] = (clean_indicator_table ['2009'].astype(float)).round(2)
clean_indicator_table ['2010'] = (clean_indicator_table ['2010'].astype(float)).round(2)
clean_indicator_table ['2011'] = (clean_indicator_table ['2011'].astype(float)).round(2)

# %%
#clean_indicator_table.iloc[:, 3:5].mean(axis=1)
#clean_indicator_table.groupby("Indicator Name")

# %%
(clean_indicator_table.assign(mean=clean_indicator_table.mean(axis=1))).round(2)
#clean_indicator_table.dtypes
# Out:
#                                                       Country Name  \
# Indicator Name
# Labor force with advanced education (% of total)    United Kingdom
# Labor force with advanced education, female (% ...  United Kingdom
# Labor force with advanced education, male (% of...  United Kingdom
# Labor force, total                                  United Kingdom
# Unemployment, female (% of female labor force)      United Kingdom
# Unemployment, male (% of male labor force)          United Kingdom
# Unemployment, total (% of total labor force)        United Kingdom
# Labor force with advanced education (% of total)             Spain
# Labor force with advanced education, female (% ...           Spain
# Labor force with advanced education, male (% of...           Spain
# Labor force, total                                           Spain
# Unemployment, female (% of female labor force)               Spain
# Unemployment, male (% of male labor force)                   Spain
# Unemployment, total (% of total labor force)                 Spain
#
#                                                    Country Code         2001  \
# Indicator Name
# Labor force with advanced education (% of total)            GBR        89.87
# Labor force with advanced education, female (% ...          GBR        87.05
# Labor force with advanced education, male (% of...          GBR        92.42
# Labor force, total                                          GBR  29259481.00
# Unemployment, female (% of female labor force)              GBR         4.10
# Unemployment, male (% of male labor force)                  GBR         5.20
# Unemployment, total (% of total labor force)                GBR         4.70
# Labor force with advanced education (% of total)            ESP        79.56
# Labor force with advanced education, female (% ...          ESP        75.28
# Labor force with advanced education, male (% of...          ESP        83.67
# Labor force, total                                          ESP  18197151.00
# Unemployment, female (% of female labor force)              ESP        15.00
# Unemployment, male (% of male labor force)                  ESP         7.40
# Unemployment, total (% of total labor force)                ESP        10.30
#
#                                                            2002         2003  \
# Indicator Name
# Labor force with advanced education (% of total)          89.76        89.80
# Labor force with advanced education, female (% ...        87.62        87.23
# Labor force with advanced education, male (% of...        91.75        92.17
# Labor force, total                                  29588608.00  29868880.00
# Unemployment, female (% of female labor force)             4.40         4.10
# Unemployment, male (% of male labor force)                 5.60         5.40
# Unemployment, total (% of total labor force)               5.00         4.80
# Labor force with advanced education (% of total)          81.00        81.60
# Labor force with advanced education, female (% ...        77.98        79.09
# Labor force with advanced education, male (% of...        83.95        84.05
# Labor force, total                                  19041481.00  19814279.00
# Unemployment, female (% of female labor force)            16.10        15.70
# Unemployment, male (% of male labor force)                 7.90         8.30
# Unemployment, total (% of total labor force)              11.10        11.30
#
#                                                            2004         2005  \
# Indicator Name
# Labor force with advanced education (% of total)          89.64        89.90
# Labor force with advanced education, female (% ...        87.48        88.00
# Labor force with advanced education, male (% of...        91.66        91.71
# Labor force, total                                  30142806.00  30589672.00
# Unemployment, female (% of female labor force)             4.20         4.30
# Unemployment, male (% of male labor force)                 4.90         5.20
# Unemployment, total (% of total labor force)               4.60         4.80
# Labor force with advanced education (% of total)          82.62        82.18
# Labor force with advanced education, female (% ...        80.40        79.69
# Labor force with advanced education, male (% of...        84.84        84.68
# Labor force, total                                  20485991.00  21257406.00
# Unemployment, female (% of female labor force)            15.10        12.00
# Unemployment, male (% of male labor force)                 8.40         7.10
# Unemployment, total (% of total labor force)              11.10         9.10
#
#                                                            2006         2007  \
# Indicator Name
# Labor force with advanced education (% of total)          89.97        89.67
# Labor force with advanced education, female (% ...        87.98        87.73
# Labor force with advanced education, male (% of...        91.92        91.59
# Labor force, total                                  31037532.00  31240727.00
# Unemployment, female (% of female labor force)             4.90         4.90
# Unemployment, male (% of male labor force)                 5.70         5.50
# Unemployment, total (% of total labor force)               5.40         5.30
# Labor force with advanced education (% of total)          82.53        82.71
# Labor force with advanced education, female (% ...        80.48        80.51
# Labor force with advanced education, male (% of...        84.61        84.94
# Labor force, total                                  21906463.00  22486832.00
# Unemployment, female (% of female labor force)            11.40        10.70
# Unemployment, male (% of male labor force)                 6.40         6.40
# Unemployment, total (% of total labor force)               8.50         8.20
#
#                                                            2008         2009  \
# Indicator Name
# Labor force with advanced education (% of total)          85.24        85.01
# Labor force with advanced education, female (% ...        82.02        81.70
# Labor force with advanced education, male (% of...        88.60        88.49
# Labor force, total                                  31647715.00  31825341.00
# Unemployment, female (% of female labor force)             5.10         6.40
# Unemployment, male (% of male labor force)                 6.10         8.50
# Unemployment, total (% of total labor force)               5.60         7.50
# Labor force with advanced education (% of total)          82.68        82.72
# Labor force with advanced education, female (% ...        80.86        81.55
# Labor force with advanced education, male (% of...        84.51        83.93
# Labor force, total                                  23119571.00  23386879.00
# Unemployment, female (% of female labor force)            12.90        18.10
# Unemployment, male (% of male labor force)                10.10        17.60
# Unemployment, total (% of total labor force)              11.30        17.90
#
#                                                            2010         2011  \
# Indicator Name
# Labor force with advanced education (% of total)          84.86        85.03
# Labor force with advanced education, female (% ...        81.62        81.29
# Labor force with advanced education, male (% of...        88.30        88.99
# Labor force, total                                  32010605.00  32192080.00
# Unemployment, female (% of female labor force)             6.90         7.30
# Unemployment, male (% of male labor force)                 8.60         8.60
# Unemployment, total (% of total labor force)               7.80         8.00
# Labor force with advanced education (% of total)          82.23        82.16
# Labor force with advanced education, female (% ...        81.57        81.64
# Labor force with advanced education, male (% of...        82.92        82.71
# Labor force, total                                  23577450.00  23614034.00
# Unemployment, female (% of female labor force)            20.20        21.80
# Unemployment, male (% of male labor force)                19.60        21.00
# Unemployment, total (% of total labor force)              19.90        21.40
#
#                                                            mean
# Indicator Name
# Labor force with advanced education (% of total)          88.07
# Labor force with advanced education, female (% ...        85.43
# Labor force with advanced education, male (% of...        90.69
# Labor force, total                                  30854858.82
# Unemployment, female (% of female labor force)             5.15
# Unemployment, male (% of male labor force)                 6.30
# Unemployment, total (% of total labor force)               5.77
# Labor force with advanced education (% of total)          82.00
# Labor force with advanced education, female (% ...        79.91
# Labor force with advanced education, male (% of...        84.07
# Labor force, total                                  21535230.64
# Unemployment, female (% of female labor force)            15.36
# Unemployment, male (% of male labor force)                10.93
# Unemployment, total (% of total labor force)              12.74

# %%
labor_force = pd.DataFrame({'Male UK Labor Force': [92.42, 91.75, 92.17, 91.66, 91.71, 91.92, 91.59, 88.60, 88.49, 88.30, 88.99],
   'Female UK Labor Force': [87.05, 87.62, 87.23, 87.48, 88.00, 87.98, 87.73, 82.02, 81.70, 81.62, 81.29], 
   'Male Spain Labor Force': [83.67, 83.95, 84.05, 84.84, 84.68, 84.61, 84.94, 84.51, 83.93, 82.92, 82.71], 
   'Female Spain Labor Force': [75.28, 77.98, 79.09, 80.40, 79.69, 80.48, 80.51, 80.86, 81.55, 81.57, 81.64]                          
   }, index=[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011])
lines = labor_force.plot(lw=1, colormap='jet', marker='.', markersize=10, title='Labor Force % With Advanced Education Between the UK and Spain')
lines.set_xlabel("Years")
lines.set_ylabel("Percentage of Labor Force")
# Out:
# Text(0, 0.5, 'Percentage of Labor Force')

# %%
#Pie Graph of Spain: Average Unemployment Total Vs Average Labor Force Total From 2001-2011

labels = ["Unemployed", "Employed"]

# The values of each section of the pie chart
sizes = [2743588.38, 18791641.6]

# The colors of each section of the pie chart
colors = ["red", "green",]

plt.pie(sizes, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title('Spain: Average Unemployment Total Vs Average Employed Total From 2001-2011')
# Out:
# Text(0.5, 1.0, 'Spain: Average Unemployment Total Vs Average Employed Total From 2001-2011')

# %%
labels = ["Unemployed", "Employed"]

# The values of each section of the pie chart
sizes = [1780325.35, 29074533.4]

# The colors of each section of the pie chart
colors = ["yellow", "pink",]

plt.pie(sizes, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title('UK: Average Unemployment Total Vs Average Employed Total From 2001-2011')
# Out:
# Text(0.5, 1.0, 'UK: Average Unemployment Total Vs Average Employed Total From 2001-2011')

# %%
unemployment = pd.DataFrame({'UK Unemployment % of Labor Force': [4.70, 5.00, 4.80, 4.60, 4.80, 5.40, 5.30, 5.60, 7.50, 7.80, 8.00],
   'Spain Unemployment % of Labor Force': [10.30, 11.10, 11.30, 11.10, 9.10, 8.50, 8.20, 11.30, 17.90, 19.90, 21.40], 
   'US Unemployment % of Labor Force': [4.73, 5.78, 5.98, 5.52, 5.08, 4.62, 4.62, 5.78, 9.25, 9.63, 8.94],                           
   }, index=[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011])
lines = unemployment.plot(lw=1, colormap='plasma', marker='.', markersize=10, title='Unemployment Total % Of Labor Force Between the UK, US, and Spain')
lines.set_xlabel("Years")
lines.set_ylabel("Unemployment Total % of Labor Force")
# Out:
# Text(0, 0.5, 'Unemployment Total % of Labor Force')
