# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file = "Resources/EDSTAT_UK&SP.csv"

ed_data =pd.read_csv(file)

ed_data.head()
# Out:
#      Country Name Country Code  \
# 0  United Kingdom          GBR
# 1  United Kingdom          GBR
# 2  United Kingdom          GBR
# 3  United Kingdom          GBR
# 4  United Kingdom          GBR
#
#                                       Indicator Name         2000  \
# 0  Expenditure on primary as % of government expe...  24.71134949
# 1  Expenditure on primary as % of total governmen...  2.980230093
# 2  Expenditure on secondary and post-secondary no...          NaN
# 3  Expenditure on secondary and post-secondary no...          NaN
# 4  Expenditure on secondary as % of government ex...  48.73329926
#
#           2001         2002         2003         2004         2005  \
# 0  24.98936081  23.62890053   25.4773407  26.19923973  26.46495056
# 1  3.071850061  3.205369949  3.469130039  3.394249916  3.489840031
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# ...

# %%
ed_data.count()
# Out:
# Country Name      104
# Country Code      104
# Indicator Name    104
# 2000               89
# 2001               91
# 2002               91
# 2003               91
# 2004               91
# 2005               93
# 2006               93
# 2007               96
# 2008               96
# 2009               96
# 2010               95
# 2011               95
# 2012               75
# 2013               93
# 2014               67
# 2015               49
# 2016               32
# dtype: int64

# %%
cleanED_df = ed_data

cleanED_df
# Out:
#        Country Name Country Code  \
# 0    United Kingdom          GBR
# 1    United Kingdom          GBR
# 2    United Kingdom          GBR
# 3    United Kingdom          GBR
# 4    United Kingdom          GBR
# ..              ...          ...
# 99            Spain          ESP
# 100           Spain          ESP
# 101           Spain          ESP
# 102           Spain          ESP
# 103           Spain          ESP
#
#                                         Indicator Name         2000  \
# 0    Expenditure on primary as % of government expe...  24.71134949
# 1    Expenditure on primary as % of total governmen...  2.980230093
# 2    Expenditure on secondary and post-secondary no...          NaN
# 3    Expenditure on secondary and post-secondary no...          NaN
# 4    Expenditure on secondary as % of government ex...  48.73329926
# ..                                                 ...          ...
# 99   Gross graduation ratio from first degree progr...  25.78824997
# ...

# %%
year10_df = cleanED_df.drop(columns=['Country Code','2000', '2012', '2013','2014','2015', '2016'])

year10_df
# Out:
#        Country Name                                     Indicator Name  \
# 0    United Kingdom  Expenditure on primary as % of government expe...
# 1    United Kingdom  Expenditure on primary as % of total governmen...
# 2    United Kingdom  Expenditure on secondary and post-secondary no...
# 3    United Kingdom  Expenditure on secondary and post-secondary no...
# 4    United Kingdom  Expenditure on secondary as % of government ex...
# ..              ...                                                ...
# 99            Spain  Gross graduation ratio from first degree progr...
# 100           Spain  Percentage of female students in tertiary educ...
# 101           Spain  Percentage of male students in tertiary educat...
# 102           Spain  Percentage of female graduates from tertiary e...
# 103           Spain  Percentage of male graduates from tertiary edu...
#
#             2001         2002         2003         2004         2005  \
# ...

# %%
# do a count of the object
#year10_df.count()
print(year10_df.dtypes)
# Out:
# Country Name      object
# Indicator Name    object
# 2001              object
# 2002              object
# 2003              object
# 2004              object
# 2005              object
# 2006              object
# 2007              object
# 2008              object
# 2009              object
# 2010              object
# 2011              object
# dtype: object

# %%
#Print out the Indicator Name value
year10_df["Indicator Name"].value_counts()
# Out:
# Expenditure on secondary and post-secondary non-tertiary vocational as % of government expenditure on education (%)       2
# GDP at market prices (current US$)                                                                                        2
# Labor force with advanced education, female (% of female labor force)                                                     2
# Government expenditure on secondary and post-secondary non-tertiary vocational education as % of GDP (%)                  2
# Labor force, total                                                                                                        2
# Labor force with advanced education, male (% of male labor force)                                                         2
# Expenditure on primary as % of government expenditure on education (%)                                                    2
# ...

# %%
gk = year10_df.groupby('Indicator Name')
M_E = gk.get_group('Percentage of male students in tertiary education enrolled in Science programmes, male (%)') 
F_E = gk.get_group('Percentage of female students in tertiary education enrolled in Science programmes, female (%)') 
M_G = gk.get_group('Percentage of male graduates from tertiary education graduating from Science programmes, male (%)') 
F_G_k = gk.get_group('Percentage of graduates from Science programmes in tertiary education who are female (%)') 
F_G_S = gk.get_group('Percentage of female graduates from tertiary education graduating from Science programmes, female (%)')

# %%
edstat.loc[edstat['Indicator Name']== 'Percentage of female students in tertiary education enrolled in Science programmes, female (%)']
# Out:
#        Country Name                                     Indicator Name  \
# 48   United Kingdom  Percentage of female students in tertiary educ...
# 100           Spain  Percentage of female students in tertiary educ...
#
#             2001         2002         2003         2004         2005  \
# 48   12.77752018  11.61071968  8.595210075  9.161129951  8.983059883
# 100  9.189860344   9.20374012  9.016019821   8.77093029   7.83618021
#
#             2006         2007         2008         2009         2010  \
# 48   8.798270226  8.694339752   8.34484005  8.361619949  8.596839905
# 100  7.199289799   6.56633997  6.198560238      6.68118   5.60777998
#
#             2011
# 48   8.604149818
# 100  6.348040104

# %%
# Enrollment  UK Male and Female Dataframe
enroll_uk_df = edstat.loc[[47, 48], :]

#enrollment_uk = enroll_df.set_index(['Country Name', 'Indicator Name']).sort_index()
enrollment_uk = enroll_df.set_index(['Country Name']).sort_index()
enrollment_uk
# Out:
#                                                    Indicator Name  \
# Country Name
# United Kingdom  Percentage of male students in tertiary educat...
# United Kingdom  Percentage of female students in tertiary educ...
#
#                        2001         2002         2003         2004  \
# Country Name
# United Kingdom  22.98771095  22.23118973   19.6115799  21.50126076
# United Kingdom  12.77752018  11.61071968  8.595210075  9.161129951
#
#                        2005         2006         2007         2008  \
# Country Name
# United Kingdom  21.14327049  20.21462059  19.67193031  19.02745056
# United Kingdom  8.983059883  8.798270226  8.694339752   8.34484005
#
#                        2009         2010         2011
# Country Name
# United Kingdom  19.01382065  19.49230957   19.7709198
# United Kingdom  8.361619949  8.596839905  8.604149818

# %%
enrollment_uk ['2001'] = enrollment_uk['2001'].astype(float)
enrollment_uk ['2002'] = enrollment_uk['2002'].astype(float)
enrollment_uk ['2003'] = enrollment_uk['2003'].astype(float)
enrollment_uk ['2004'] = enrollment_uk['2004'].astype(float)
enrollment_uk ['2005'] = enrollment_uk['2005'].astype(float)
enrollment_uk ['2006'] = enrollment_uk['2006'].astype(float)
enrollment_uk ['2007'] = enrollment_uk['2007'].astype(float)
enrollment_uk ['2008'] = enrollment_uk['2008'].astype(float)
enrollment_uk ['2009'] = enrollment_uk['2009'].astype(float)
enrollment_uk ['2010'] = enrollment_uk['2001'].astype(float)
enrollment_uk ['2011'] = enrollment_uk['2011'].astype(float)
print(enrollment_uk.dtypes)
# Out:
# Indicator Name     object
# 2001              float64
# 2002              float64
# 2003              float64
# 2004              float64
# 2005              float64
# 2006              float64
# 2007              float64
# 2008              float64
# 2009              float64
# 2010              float64
# 2011              float64
# dtype: object

# %%
enrollment_uk['Indicator Name'].replace({"Percentage of male students in tertiary education enrolled in Science programmes, male (%)":"enroll_uk_male","Percentage of female students in tertiary education enrolled in Science programmes, female (%)":"enroll_uk_female"}, inplace=True)

enrollment_uk
# Out:
#                   Indicator Name       2001      2002      2003       2004  \
# Country Name
# United Kingdom    enroll_uk_male  22.987711  22.23119  19.61158  21.501261
# United Kingdom  enroll_uk_female  12.777520  11.61072   8.59521   9.161130
#
#                     2005       2006      2007       2008       2009  \
# Country Name
# United Kingdom  21.14327  20.214621  19.67193  19.027451  19.013821
# United Kingdom   8.98306   8.798270   8.69434   8.344840   8.361620
#
#                      2010      2011
# Country Name
# United Kingdom  22.987711  19.77092
# United Kingdom  12.777520   8.60415

# %%
#Line chart
plt.plot( enrollment_uk.iloc[0, 2:13], label="UK_enroll_male", marker='o')
plt.plot(enrollment_uk.iloc[1, 2:13], label="UK_enroll_female", marker='o')

plt.title("UK_enroll Male vs Female ")
plt.xlabel("years")
plt.ylabel("Percentage")
plt.legend()

# %%
# Bar chart for enrollment in the UK Male and Female
enrollment_uk.plot(x="Indicator Name", y=["2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010", "2011"], kind="bar")
plt.show()

# %%
uk_enroll = enrollment_uk.set_index(['Indicator Name']).sort_index()

uk_enroll
# Out:
#                        2001      2002      2003       2004      2005  \
# Indicator Name
# enroll_uk_female  12.777520  11.61072   8.59521   9.161130   8.98306
# enroll_uk_male    22.987711  22.23119  19.61158  21.501261  21.14327
#
#                        2006      2007       2008       2009       2010  \
# Indicator Name
# enroll_uk_female   8.798270   8.69434   8.344840   8.361620  12.777520
# enroll_uk_male    20.214621  19.67193  19.027451  19.013821  22.987711
#
#                       2011
# Indicator Name
# enroll_uk_female   8.60415
# enroll_uk_male    19.77092

# %%
# UK enrollment male vs female average between the 10 years 
avg_row = enrollment_uk.mean(axis=1)
print(avg_row)
# Out:
# Country Name
# United Kingdom    20.741951
# United Kingdom     9.700762
# dtype: float64

# %%
#UK pie chart for enrollment
labels = ['female_uk_enroll', 'male_uk_enroll']
sizes = [9.700762, 20.741951]
colors = ["lightcoral","orange"]
explode = (0,0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x2cb58eafd60>,
# ...
#  [Text(-1.0499044455953552, -0.3281777797461457, 'female_uk_enroll'),
#   Text(1.0499044148691294, 0.32817787804529297, 'male_uk_enroll')],
#  [Text(-0.572675152142921, -0.1790060616797158, '31.9%'),
#   Text(0.5726751353831614, 0.17900611529743252, '68.1%')])

# %%
#Both UK and SP enrollment pie chart for enrollment
labels = ['female_uk_enroll', 'male_uk_enroll']
sizes = [9.700762, 20.741951]
colors = ["lightcoral","orange"]
explode = (0,0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=140)

# %%
#enrollment_uk_df = enrollment_uk.T.reset_index()

#enrollment_uk_df

# %%
# Enrollment Spain Female and Male
enroll_sp_df = edstat.loc[[ 100, 101], :]

enrollment_sp = enroll_sp_df.set_index(['Country Name']).sort_index()

enrollment_sp
# Out:
#                                                  Indicator Name         2001  \
# Country Name
# Spain         Percentage of female students in tertiary educ...  9.189860344
# Spain         Percentage of male students in tertiary educat...  17.09576988
#
#                      2002         2003         2004        2005         2006  \
# Country Name
# Spain          9.20374012  9.016019821   8.77093029  7.83618021  7.199289799
# Spain         17.82360077  18.51619911  18.23263931  17.2570591  16.25740051
#
#                      2007         2008         2009         2010         2011
# Country Name
# Spain          6.56633997  6.198560238      6.68118   5.60777998  6.348040104
# Spain         15.10367012  14.32921028  14.71730042  13.23748016  13.74894047

# %%
#enrollment_sp_df = enrollment_sp.T.reset_index()

#enrollment_sp_df

# %%
enrollment_sp ['2001'] = enrollment_sp['2001'].astype(float)
enrollment_sp ['2002'] = enrollment_sp['2002'].astype(float)
enrollment_sp ['2003'] = enrollment_sp['2003'].astype(float)
enrollment_sp ['2004'] = enrollment_sp['2004'].astype(float)
enrollment_sp ['2005'] = enrollment_sp['2005'].astype(float)
enrollment_sp ['2006'] = enrollment_sp['2006'].astype(float)
enrollment_sp ['2007'] = enrollment_sp['2007'].astype(float)
enrollment_sp ['2008'] = enrollment_sp['2008'].astype(float)
enrollment_sp ['2009'] = enrollment_sp['2009'].astype(float)
enrollment_sp ['2010'] = enrollment_sp['2001'].astype(float)
enrollment_sp ['2011'] = enrollment_sp['2011'].astype(float)
print(enrollment_sp.dtypes)
# Out:
# Indicator Name     object
# 2001              float64
# 2002              float64
# 2003              float64
# 2004              float64
# 2005              float64
# 2006              float64
# 2007              float64
# 2008              float64
# 2009              float64
# 2010              float64
# 2011              float64
# dtype: object

# %%
enrollment_sp['Indicator Name'].replace({"Percentage of male students in tertiary education enrolled in Science programmes, male (%)":"enroll_sp_male","Percentage of female students in tertiary education enrolled in Science programmes, female (%)":"enroll_sp_female"}, inplace=True)

enrollment_sp
# Out:
#                 Indicator Name      2001       2002       2003       2004  \
# Country Name
# Spain         enroll_sp_female   9.18986   9.203740   9.016020   8.770930
# Spain           enroll_sp_male  17.09577  17.823601  18.516199  18.232639
#
#                    2005       2006      2007      2008      2009      2010  \
# Country Name
# Spain          7.836180   7.199290   6.56634   6.19856   6.68118   9.18986
# Spain         17.257059  16.257401  15.10367  14.32921  14.71730  17.09577
#
#                   2011
# Country Name
# Spain          6.34804
# Spain         13.74894

# %%
sp_enroll = enrollment_sp.set_index(['Indicator Name']).sort_index()

sp_enroll
# Out:
#                       2001       2002       2003       2004       2005  \
# Indicator Name
# enroll_sp_female   9.18986   9.203740   9.016020   8.770930   7.836180
# enroll_sp_male    17.09577  17.823601  18.516199  18.232639  17.257059
#
#                        2006      2007      2008      2009      2010      2011
# Indicator Name
# enroll_sp_female   7.199290   6.56634   6.19856   6.68118   9.18986   6.34804
# enroll_sp_male    16.257401  15.10367  14.32921  14.71730  17.09577  13.74894

# %%
#Line chart
plt.plot( sp_enroll.iloc[1, 2:13], label="SP_enroll_male", marker='o')
plt.plot(sp_enroll.iloc[0, 2:13], label="SP_enroll_female", marker='o')

plt.title("SP_enroll Male vs Female ")
plt.xlabel("years")
plt.ylabel("Percentage")
plt.legend()

# %%
# Bar chart for enrollment in the Spain Male and Female
enrollment_sp.plot(x="Indicator Name", y=["2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010", "2011"], kind="bar")
plt.show()

# %%
#UK and SP Enroll
plt.plot( enrollment_uk.iloc[0, 2:13], label="UK_enroll_male", marker='o')
plt.plot(enrollment_uk.iloc[1, 2:13], label="UK_enroll_female", marker='o')
plt.plot( sp_enroll.iloc[1, 2:13], label="SP_enroll_male", marker='o')
plt.plot(sp_enroll.iloc[0, 2:13], label="SP_enroll_female", marker='o')

plt.title("UK & SP enroll Male vs Female ")
plt.xlabel("years")
plt.ylabel("Percentage")
plt.legend()

# %%
# SP enrollment male vs female average between the 10 years 
avg_row_sp = enrollment_sp.mean(axis=1)
print(avg_row_sp)
# Out:
# Country Name
# Spain     7.836364
# Spain    16.379778
# dtype: float64

# %%
#SP pie chart for enrollment
labels = ['female_sp_enroll', 'male_sp_enroll']
sizes = [7.836364, 16.379778]
colors = ["lightskyblue","red"]
explode = (0,0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x2cb5692ebe0>,
# ...
#  [Text(-1.0446801338784855, -0.34444653849273854, 'female_sp_enroll'),
#   Text(1.0446801016290688, 0.34444663630274996, 'male_sp_enroll')],
#  [Text(-0.569825527570083, -0.18787993008694828, '32.4%'),
#   Text(0.569825509979492, 0.18787998343786358, '67.6%')])

# %%
#Both UK and SP pie chart for enrollment
labels = ['female_sp_enroll', 'male_sp_enroll','female_uk_enroll', 'male_uk_enroll']
sizes = [7.836364, 16.379778, 9.700762, 20.741951]
colors = ["lightskyblue","red","lightcoral","orange"]
explode = (0,0, 0, 0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x2cb58de3f10>,
# ...
#  [Text(-1.066419788800902, 0.2697199177922162, 'female_sp_enroll'),
#   Text(-0.45522196128372483, -1.0013855231453064, 'male_sp_enroll'),
#   Text(0.9661583427759033, -0.525868858827484, 'female_uk_enroll'),
#   Text(0.34550856613412995, 1.0443293688908388, 'male_uk_enroll')],
#  [Text(-0.5816835211641282, 0.14711995515939066, '14.3%'),
#   Text(-0.24830288797294078, -0.5462102853519852, '30.0%'),
#   Text(0.5269954596959472, -0.2868375593604458, '17.7%'),
#   Text(0.1884592178913436, 0.5696342012131848, '37.9%')])

# %%
# graduate UK Male and Female Dataframe
grad_uk_df = edstat.loc[[49, 50], :]

graduate_uk = enroll_df.set_index(['Country Name']).sort_index()

graduate_uk
# Out:
#                                                    Indicator Name  \
# Country Name
# United Kingdom  Percentage of male students in tertiary educat...
# United Kingdom  Percentage of female students in tertiary educ...
#
#                        2001         2002         2003         2004  \
# Country Name
# United Kingdom  22.98771095  22.23118973   19.6115799  21.50126076
# United Kingdom  12.77752018  11.61071968  8.595210075  9.161129951
#
#                        2005         2006         2007         2008  \
# Country Name
# United Kingdom  21.14327049  20.21462059  19.67193031  19.02745056
# United Kingdom  8.983059883  8.798270226  8.694339752   8.34484005
#
#                        2009         2010         2011
# Country Name
# United Kingdom  19.01382065  19.49230957   19.7709198
# United Kingdom  8.361619949  8.596839905  8.604149818

# %%
graduate_uk ['2001'] = graduate_uk['2001'].astype(float)
graduate_uk ['2002'] = graduate_uk['2002'].astype(float)
graduate_uk ['2003'] = graduate_uk['2003'].astype(float)
graduate_uk ['2004'] = graduate_uk['2004'].astype(float)
graduate_uk ['2005'] = graduate_uk['2005'].astype(float)
graduate_uk ['2006'] = graduate_uk['2006'].astype(float)
graduate_uk ['2007'] = graduate_uk['2007'].astype(float)
graduate_uk ['2008'] = graduate_uk['2008'].astype(float)
graduate_uk ['2009'] = graduate_uk['2009'].astype(float)
graduate_uk ['2010'] = graduate_uk['2001'].astype(float)
graduate_uk ['2011'] = graduate_uk['2011'].astype(float)
print(graduate_uk.dtypes)
# Out:
# Indicator Name     object
# 2001              float64
# 2002              float64
# 2003              float64
# 2004              float64
# 2005              float64
# 2006              float64
# 2007              float64
# 2008              float64
# 2009              float64
# 2010              float64
# 2011              float64
# dtype: object

# %%
graduate_uk['Indicator Name'].replace({"Percentage of male graduates from tertiary education graduating from Science programmes, male (%)":"grad_uk_male","Percentage of graduates from Science programmes in tertiary education who are female (%)":"grad_uk_female"}, inplace=True)

graduate_uk
# Out:
#                                                    Indicator Name       2001  \
# Country Name
# United Kingdom  Percentage of male students in tertiary educat...  22.987711
# United Kingdom  Percentage of female students in tertiary educ...  12.777520
#
#                     2002      2003       2004      2005       2006      2007  \
# Country Name
# United Kingdom  22.23119  19.61158  21.501261  21.14327  20.214621  19.67193
# United Kingdom  11.61072   8.59521   9.161130   8.98306   8.798270   8.69434
#
#                      2008       2009       2010      2011
# Country Name
# United Kingdom  19.027451  19.013821  22.987711  19.77092
# United Kingdom   8.344840   8.361620  12.777520   8.60415

# %%
row1 = graduate_uk.iloc[0, 1:12]
row2 = graduate_uk.iloc[1, 1:12]
plt.plot( row1, label='Male')
plt.plot( row2, label='female')

# %%
# Bar chart for graduate UK Male and Female
graduate_uk.plot(x="Indicator Name", y=["2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010", "2011"], kind="bar")
plt.show()

# %%
graduate_uk.plot(kind='line', x='')

# %%
avg_row_GUK = graduate_uk.mean(axis=1)
print(avg_row_GUK)
# Out:
# Country Name
# United Kingdom    20.741951
# United Kingdom     9.700762
# dtype: float64

# %%
#UK pie chart for Graduate
labels = ['female_uk_grad', 'male_uk_grad']
sizes = [9.700762, 20.741951]
colors = ["Pink","Brown"]
explode = (0,0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x2cb5917f520>,
# ...
#  [Text(-1.0499044455953552, -0.3281777797461457, 'female_uk_grad'),
#   Text(1.0499044148691294, 0.32817787804529297, 'male_uk_grad')],
#  [Text(-0.572675152142921, -0.1790060616797158, '31.9%'),
#   Text(0.5726751353831614, 0.17900611529743252, '68.1%')])

# %%
#graduate_uk.T.reset_index()

# %%
# graduate Spain Male and Female Dataframe
grad_sp_df = edstat.loc[[102, 103], :]

graduate_sp = enroll_df.set_index(['Country Name']).sort_index()

graduate_sp
# Out:
#                                                    Indicator Name  \
# Country Name
# United Kingdom  Percentage of male students in tertiary educat...
# United Kingdom  Percentage of female students in tertiary educ...
#
#                        2001         2002         2003         2004  \
# Country Name
# United Kingdom  22.98771095  22.23118973   19.6115799  21.50126076
# United Kingdom  12.77752018  11.61071968  8.595210075  9.161129951
#
#                        2005         2006         2007         2008  \
# Country Name
# United Kingdom  21.14327049  20.21462059  19.67193031  19.02745056
# United Kingdom  8.983059883  8.798270226  8.694339752   8.34484005
#
#                        2009         2010         2011
# Country Name
# United Kingdom  19.01382065  19.49230957   19.7709198
# United Kingdom  8.361619949  8.596839905  8.604149818

# %%
#graduate_uk.T.reset_index()

# %%
graduate_sp['Indicator Name'].replace({"Percentage of male graduates from tertiary education graduating from Science programmes, male (%)":"grad_sp_male","Percentage of female graduates from tertiary education graduating from Science programmes, female (%)":"grad_sp_female"}, inplace=True)

graduate_sp
# Out:
#                                                    Indicator Name  \
# Country Name
# United Kingdom  Percentage of male students in tertiary educat...
# United Kingdom  Percentage of female students in tertiary educ...
#
#                        2001         2002         2003         2004  \
# Country Name
# United Kingdom  22.98771095  22.23118973   19.6115799  21.50126076
# United Kingdom  12.77752018  11.61071968  8.595210075  9.161129951
#
#                        2005         2006         2007         2008  \
# Country Name
# United Kingdom  21.14327049  20.21462059  19.67193031  19.02745056
# United Kingdom  8.983059883  8.798270226  8.694339752   8.34484005
#
#                        2009         2010         2011
# Country Name
# United Kingdom  19.01382065  19.49230957   19.7709198
# United Kingdom  8.361619949  8.596839905  8.604149818

# %%
#Spain graduate

row3 = graduate_sp.iloc[0, 1:12]
row4 = graduate_sp.iloc[1, 1:12]
plt.plot( row3, label='Male')
plt.plot( row4, label='female')

# %%
#UK and Spain
row1 = graduate_uk.iloc[0, 1:12]
row2 = graduate_uk.iloc[1, 1:12]
plt.plot( row1, label='Male')
plt.plot( row2, label='female')
row3 = graduate_sp.iloc[0, 1:12]
row4 = graduate_sp.iloc[1, 1:12]
plt.plot( row3, label='Male')
plt.plot( row4, label='female')

# %%
plt.plot( graduate_uk.iloc[0, 1:12], label="UK_grad_male", marker='o')
plt.plot(graduate_uk.iloc[1, 1:12], label="UK_grad_female", marker='o')
plt.plot( graduate_sp.iloc[0, 1:12], label="SP_grad_male", marker='o')
plt.plot(graduate_sp.iloc[1, 1:12], label="SP_grad_female", marker='o')

plt.title("UK & SP grad Male vs Female ")
plt.xlabel("years")
plt.ylabel("Percentage")
plt.legend()

# %%
graduate_sp ['2001']= graduate_sp['2001'].astype(float)
graduate_sp['2002']= graduate_sp['2002'].astype(float)
graduate_sp['2003']= graduate_sp['2003'].astype(float)
graduate_sp['2004']= graduate_sp['2004'].astype(float)
graduate_sp['2005']= graduate_sp['2005'].astype(float)
graduate_sp['2006']= graduate_sp['2006'].astype(float)
graduate_sp['2007']= graduate_sp['2007'].astype(float)
graduate_sp['2008']= graduate_sp['2008'].astype(float)
graduate_sp['2009']= graduate_sp['2009'].astype(float)
graduate_sp['2010']= graduate_sp['2010'].astype(float)
graduate_sp['2011']= graduate_sp['2011'].astype(float)
print(graduate_sp.dtypes)
# Out:
# Indicator Name     object
# 2001              float64
# 2002              float64
# 2003              float64
# 2004              float64
# 2005              float64
# 2006              float64
# 2007              float64
# 2008              float64
# 2009              float64
# 2010              float64
# 2011              float64
# dtype: object

# %%
graduate_sp.plot(x="Indicator Name", y=["2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010", "2011"], kind="bar")
plt.show()

# %%
avg_row_GSP = graduate_sp.mean(axis=1)
print(avg_row_GSP)
# Out:
# Country Name
# United Kingdom    20.424188
# United Kingdom     9.320700
# dtype: float64

# %%
#SP pie chart for Graduate
labels = ['female_sp_grad', 'male_sp_grad']
sizes = [9.320700, 20.424188]
colors = ["Violet","Tan"]
explode = (0,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x2cb59382730>,
# ...
#  [Text(-1.055224550417049, -0.3106463394233663, 'female_sp_grad'),
#   Text(1.055224550417049, 0.3106463394233661, 'male_sp_grad')],
#  [Text(-0.5755770275002084, -0.16944345786729068, '31.3%'),
#   Text(0.5755770275002084, 0.1694434578672906, '68.7%')])

# %%
#SP and UK pie chart for Graduate
labels = ['female_sp_grad', 'male_sp_grad','female_uk_grad', 'male_uk_grad']
sizes = [9.320700, 20.424188, 9.700762, 20.741951]
colors = ["Violet","Tan","Pink","Brown"]
explode = (0,0,0,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x2cb593c1df0>,
# ...
#  [Text(-1.0754606185790967, 0.23105076906486804, 'female_sp_grad'),
#   Text(-0.25059765471546375, -1.0710746077893498, 'male_sp_grad'),
#   Text(1.0714806674567932, -0.2488557398702011, 'female_uk_grad'),
#   Text(0.22930164761284744, 1.075834910384504, 'male_uk_grad')],
#  [Text(-0.5866148828613253, 0.12602769221720075, '15.5%'),
#   Text(-0.1366896298447984, -0.5842225133396453, '33.9%'),
#   Text(0.584444000430978, -0.13573949447465514, '16.1%'),
#   Text(0.12507362597064406, 0.5868190420279111, '34.5%')])

# %%
#Average enrollment for male and female in Science program in the UK & Spain in 10 years
average_enroll_2001 = Float_Years['2001'].mean()
average_enroll_2002 = Float_Years['2002'].mean()
average_enroll_2003 = Float_Years['2003'].mean()
average_enroll_2004 = Float_Years['2004'].mean()
average_enroll_2005 = Float_Years['2005'].mean()
average_enroll_2006 = Float_Years['2006'].mean()
average_enroll_2007 = Float_Years['2007'].mean()
average_enroll_2008 = Float_Years['2008'].mean()
average_enroll_2009 = Float_Years['2009'].mean()
average_enroll_2010 = Float_Years['2010'].mean()
average_enroll_2011 = Float_Years['2011'].mean()

average_enroll_data = pd.DataFrame({"Average Enroll 2001" : [average_enroll_2001],
                                      "Average Enroll 2002" : [average_enroll_2002],
                                     "Average Enroll 2003" : [average_enroll_2003],
                                     "Average Enroll 2004" : [average_enroll_2004],
                                     "Average Enroll 2005" : [average_enroll_2005],
                                     "Average Enroll 2006" : [average_enroll_2006],
                                     "Average Enroll 2007" : [average_enroll_2007],
                                     "Average Enroll 2008" : [average_enroll_2008],
                                     "Average Enroll 2009" : [average_enroll_2009],
                                     "Average Enroll 2010" : [average_enroll_2010],
                                     "Average Enroll 2011" : [average_enroll_2011]
    
})

average_enroll_data
# Out:
#    Average Enroll 2001  Average Enroll 2002  Average Enroll 2003  \
# 0            15.512715            15.217313            13.934752
#
#    Average Enroll 2004  Average Enroll 2005  Average Enroll 2006  \
# 0             14.41649            13.804892            13.117395
#
#    Average Enroll 2007  Average Enroll 2008  Average Enroll 2009  \
# 0             12.50907            11.975015             12.19348
#
#    Average Enroll 2010  Average Enroll 2011
# 0            11.733602            12.118013
